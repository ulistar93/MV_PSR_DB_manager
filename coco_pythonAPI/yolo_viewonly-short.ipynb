# %%
# %matplotlib inline

import os
import pathlib
import numpy as np
import cv2
import json
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from pyyolo import YTS

# %%
dataDir='./ts'
tsdataFile='./ts_data.data'
plt.rcParams['figure.figsize'] = [21,10]

# %%
ts = YTS(tsdataFile, dataDir)
# Out:
# loading annotations into memory...
# DONE (t=0.00s)

# %%
ts.getImgIds()
# Out:
# ['00000',
#  '00001',
#  '00002',
#  '00003',
#  '00004',
#  '00005',
#  '00006',
#  '00007',
#  '00008',
#  '00009',
#  '00010',
#  '00011',
#  '00012',
#  '00013',
#  '00014',
#  '00015',
#  '00016',
#  '00017',
#  '00018',
#  '00019',
#  '00020',
#  '00021',
#  '00022',
#  '00023',
#  '00024',
#  '00025',
#  '00026',
#  '00027',
#  '00028',
#  '00029',
#  '00030',
#  '00031',
#  '00032',
#  '00033',
#  '00034',
#  '00035',
#  '00036',
#  '00037',
#  '00038',
#  '00039',
#  '00040',
#  '00041',
#  '00042',
#  '00043',
#  '00044',
#  '00045',
#  '00046',
#  '00047',
#  '00048',
#  '00049',
#  '00050',
#  '00051',
#  '00052',
#  '00053',
#  '00054',
#  '00055',
#  '00056',
#  '00057',
#  '00058',
#  '00059',
#  '00060',
#  '00061',
#  '00062',
#  '00063',
#  '00064',
#  '00065',
#  '00066',
#  '00067',
#  '00068',
#  '00069',
#  '00070',
#  '00071',
#  '00072',
#  '00073',
#  '00074',
#  '00075',
#  '00076',
#  '00077',
#  '00078',
#  '00079',
#  '00080',
#  '00081',
#  '00082',
# ...

# %%
#imgs = ts.loadImg(['00074','00256'])
#img = imgs[0]
#img = ts.loadImg('00074')
#anno = ts.getAnno('00074')
#annos = ts.getAnno(['00074','00256'])
#anno = annos[0]
#imgs = ts.loadImg(['00074','00256'])

pair = ts.getImgAnnoPair(['00074','00256'])
img, anno = pair[0]

plt.imshow(img); plt.axis('off')
ts.showAnns(anno)
# Out:
# DONE (t=0.02s)
